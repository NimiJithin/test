# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import pandasql as sql
import os
import math
import seaborn as sns
from datetime import datetime
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from functools import reduce
from scipy import stats
from math import sqrt

# %%
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg/'
# segfileArray = []
# segrmseArray = []
# # a = [41,42,45,46,51,54,59,60,63,64,68,69,70,73,77,79,80,87,90,93]
# a=[36,43,48,50,62,76]
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segfileArray.append(int(messFile[0]))
#         segrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-hour/'
# seghourfileArray = []
# seghourrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         seghourfileArray.append(int(messFile[0]))
#         seghourrmseArray.append(float(rmse[0]))
        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-month-hr/'
# segMonthhourfileArray = []
# segMonthhourrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segMonthhourfileArray.append(int(messFile[0]))
#         segMonthhourrmseArray.append(float(rmse[0]))

    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-month/'
# segmonthsegfileArray = []
# segmonthrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthsegfileArray.append(int(messFile[0]))
#         segmonthrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-month-cyclic/'
# segmonthcyclifileArray = []
# segmonthcyclirmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthcyclifileArray.append(int(messFile[0]))
#         segmonthcyclirmseArray.append(float(rmse[0]))
        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-month-startTemp/'
# segmonthStartTempfileArray = []
# segmonthStartTemprmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthStartTempfileArray.append(int(messFile[0]))
#         segmonthStartTemprmseArray.append(float(rmse[0]))
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/temp/seg-timeStamp/'
# segtimeStampfileArray = []
# segtimeStamprmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segtimeStampfileArray.append(int(messFile[0]))
#         segtimeStamprmseArray.append(float(rmse[0]))

# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/stat/Temp/'
# statfileArray = []
# statrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         statfileArray.append(int(messFile[0]))
#         statrmseArray.append(float(rmse[0]))
    

# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/Temp/seg-month'
# rffileArray = []
# rfrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         rffileArray.append(int(messFile[0]))
#         rfrmseArray.append(float(rmse[0]))

# #------------------------------------LineraRegression

        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg/'
# segfileArray = []
# segrmseArray = []
# # a = [41,42,45,46,51,54,59,60,63,64,68,69,70,73,77,79,80,87,90,93]
# a=[36,43,48,50,62,76]
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segfileArray.append(int(messFile[0]))
#         segrmseArray.append(float(rmse[0]))

        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-month-startTemp/'
# LRfileArray = []
# LRrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         LRfileArray.append(int(messFile[0]))
#         LRrmseArray.append(float(rmse[0]))

# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-hour/'
# seghourfileArray = []
# seghourrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         seghourfileArray.append(int(messFile[0]))
#         seghourrmseArray.append(float(rmse[0]))
        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-month-hr/'
# segMonthhourfileArray = []
# segMonthhourrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segMonthhourfileArray.append(int(messFile[0]))
#         segMonthhourrmseArray.append(float(rmse[0]))

    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-month/'
# segmonthsegfileArray = []
# segmonthrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthsegfileArray.append(int(messFile[0]))
#         segmonthrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-month-cyclic/'
# segmonthcyclifileArray = []
# segmonthcyclirmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthcyclifileArray.append(int(messFile[0]))
#         segmonthcyclirmseArray.append(float(rmse[0]))
        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-month-startTemp/'
# segmonthStartTempfileArray = []
# segmonthStartTemprmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthStartTempfileArray.append(int(messFile[0]))
#         segmonthStartTemprmseArray.append(float(rmse[0]))
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/weightedLinearRegression/temp/seg-timeStamp/'
# segtimeStampfileArray = []
# segtimeStamprmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segtimeStampfileArray.append(int(messFile[0]))
#         segtimeStamprmseArray.append(float(rmse[0]))

#------------------------------------------RandomForest
        
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg/'
segfileArray = []
segrmseArray = []
# a = [41,42,45,46,51,54,59,60,63,64,68,69,70,73,77,79,80,87,90,93]
a=[36,43,48,50,62,76]
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segfileArray.append(int(messFile[0]))
        segrmseArray.append(float(rmse[0]))



srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-hour/'
seghourfileArray = []
seghourrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        seghourfileArray.append(int(messFile[0]))
        seghourrmseArray.append(float(rmse[0]))
        
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-month-hr/'
segMonthhourfileArray = []
segMonthhourrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segMonthhourfileArray.append(int(messFile[0]))
        segMonthhourrmseArray.append(float(rmse[0]))

    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-month/'
segmonthsegfileArray = []
segmonthrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthsegfileArray.append(int(messFile[0]))
        segmonthrmseArray.append(float(rmse[0]))
    
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-month-cyclic/'
segmonthcyclifileArray = []
segmonthcyclirmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthcyclifileArray.append(int(messFile[0]))
        segmonthcyclirmseArray.append(float(rmse[0]))
        
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-month-startTemp/'
segmonthStartTempfileArray = []
segmonthStartTemprmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthStartTempfileArray.append(int(messFile[0]))
        segmonthStartTemprmseArray.append(float(rmse[0]))
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/temp/seg-timeStamp/'
segtimeStampfileArray = []
segtimeStamprmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segtimeStampfileArray.append(int(messFile[0]))
        segtimeStamprmseArray.append(float(rmse[0]))

# %%
fig = plt.figure()
ax = fig.subplots()

ax.grid(which='both')
ax.set_xlabel("Measurement File")
ax.set_ylabel("RMSE(Temperature)")
plt.rcParams["figure.figsize"] = (20,5)
major_ticks = np.arange(0, 100, 2)
minor_ticks = np.arange(0, 100, 1)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)

# major_ticksy = np.arange(0, 5, 1)
# minor_ticksy = np.arange(0, 5, 1)

# ax.set_yticks(major_ticksy)
# ax.set_yticks(minor_ticksy, minor=True)

plt.plot(segfileArray,segrmseArray,c='pink', label='wknn-Segment')
plt.legend(loc='best')

plt.plot(seghourfileArray,seghourrmseArray, c='blue', label='wknn-Segment-Hour')
plt.legend(loc='best')

plt.plot(segmonthsegfileArray,segmonthrmseArray, c='green', label='wknn-Segment-Month')
plt.legend(loc='best')

plt.plot(segmonthStartTempfileArray,segmonthStartTemprmseArray, c='red', label='wknn-Segment-Start-Temperature')
plt.legend(loc='best')

plt.plot(segmonthcyclifileArray,segmonthcyclirmseArray, c='orange', label='wknn-Segment-Month-Cyclic')
plt.legend(loc='best')

plt.scatter(segtimeStampfileArray,segtimeStamprmseArray, c='pink', label='wknn-Segment-timestamp')
plt.legend(loc='best')

plt.plot(statfileArray, statrmseArray, c='black', label='mean-Segment')
plt.legend(loc='best')

plt.plot(rffileArray, rfrmseArray, c='cyan', label='Random Forest-Segment')
plt.legend(loc='best')

plt.plot(LRfileArray, LRrmseArray, c='black', label='Weighted Linear Regression')
plt.legend(loc='best')
#plt.ylim(0, 8)


# sns.distplot(segrmseArray, kde=True,
#              bins=segfileArray, color = 'darkblue',
#              kde_kws={"label": "Segment","linewidth": 2})

# sns.distplot(seghourrmseArray, kde=True,
#              bins=seghourfileArray, color = 'maroon',
#              kde_kws={"label": "Segment-Hour", "linewidth": 2})

# sns.distplot(segmonthrmseArray, kde=True,
#              bins=segmonthsegfileArray, color = 'orange',
#              kde_kws={"label": "Segment-Month", "linewidth":2})

# sns.distplot(segmonthcyclirmseArray, kde=True,
#              bins=segmonthcyclifileArray, color = 'green',
#              kde_kws={"label": "Segment-Month-Cyclic","linewidth": 2})

# sns.distplot(segtimeStamprmseArray, kde=True,
#              bins=segtimeStampfileArray, color = 'pink',
#              kde_kws={"label": "Segment-Timestamp", "linewidth": 3})

# sns.distplot(statsegrmseArray, kde=True,
#              bins=statsegfileArray, color = 'black',
#              kde_kws={"label": "mean-Segment", "linewidth": 3})
#plt.ylim(0, 8)

# %%
# print("wknn-Seg===>", np.sum(segrmseArray)/6)
# print("wknn-Seg-Hour===>",np.sum(seghourrmseArray)/6)
# print("wknn-Seg-MonthCyclic===>",np.sum(segmonthcyclirmseArray)/6)
# print("wknn-Seg-Month===>",np.sum(segmonthrmseArray)/6)
# print("wknn-Seg-Month-Hour===>",np.sum(segMonthhourrmseArray)/6)
# print("wknn-Seg-Month-StartTemp===>", np.sum(segmonthStartTemprmseArray)/6)
# print("wknn-Seg-TimeStamp===>",np.sum(segtimeStamprmseArray)/6)


# print("LinearRegression-Seg===>", np.sum(segrmseArray)/6)
# print("LinearRegression-Seg-Hour===>",np.sum(seghourrmseArray)/6)
# print("LinearRegression-Seg-MonthCyclic===>",np.sum(segmonthcyclirmseArray)/6)
# print("LinearRegression-Seg-Month===>",np.sum(segmonthrmseArray)/6)
# print("LinearRegression-Seg-Month-Hour===>",np.sum(segMonthhourrmseArray)/6)
# print("LinearRegression-Seg-Month-StartTemp===>", np.sum(segmonthStartTemprmseArray)/6)
# print("LinearRegression-Seg-TimeStamp===>",np.sum(segtimeStamprmseArray)/6)


print("RandomForest-Seg===>", np.sum(segrmseArray)/6)
print("RandomForest-Seg-Hour===>",np.sum(seghourrmseArray)/6)
print("RandomForest-Seg-Month===>",np.sum(segmonthrmseArray)/6)
print("RandomForest-Seg-MonthCyclic===>",np.sum(segmonthcyclirmseArray)/6)
print("RandomForest-Seg-Month-Hour===>",np.sum(segMonthhourrmseArray)/6)
print("RandomForest-Seg-TimeStamp===>",np.sum(segtimeStamprmseArray)/6)
print("RandomForest-Seg-StartTemp===>", np.sum(segmonthStartTemprmseArray)/6)

# print("Mean Prediction===>",np.sum(statrmseArray)/6)
# print("Random Forest -Seg -Month===>",np.sum(rfrmseArray)/6)
# Out:
# RandomForest-Seg===> 8.846890341475913
# RandomForest-Seg-Hour===> 13.453729808008925
# RandomForest-Seg-Month===> 12.505313701120869
# RandomForest-Seg-MonthCyclic===> 2.3320118324237087
# RandomForest-Seg-Month-Hour===> 2.3237403337971054
# RandomForest-Seg-TimeStamp===> 12.67553685465649
# RandomForest-Seg-StartTemp===> 1.5346059180397713

# %%
segtimeStamprmseArray
# Out:
# [14.595663882436586,
#  10.893257990406491,
#  0.7877413358978275,
#  18.7501540320844,
#  15.641891243003728,
#  15.384512644109899]

# %%
 df = pd.DataFrame({'MessFile': [],'Segment': [] ,
                'seg-hour': [],
                'seg-month': [],
                'seg-month-cyclic': [],
                'seg-timeStamp': [],
                'stat': [],
                'randomseg-month1': []})

# %%
# a = [35,41,42,45,46,51,54,59,60,63,64,68,69,70,73,77,79,80,87,90,92,93]
a = [36,37,47,52,57,66,70]

# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg/'
# segfileArray = []
# segrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segfileArray.append(int(messFile[0]))
#         segrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg-hour/'
# seghourfileArray = []
# seghourrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         seghourfileArray.append(int(messFile[0]))
#         seghourrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg-month/'
# segmonthsegfileArray = []
# segmonthrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthsegfileArray.append(int(messFile[0]))
#         segmonthrmseArray.append(float(rmse[0]))
        
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg-month-hr/'
# segmonthHrsegfileArray = []
# segmonthHrrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthHrsegfileArray.append(int(messFile[0]))
#         segmonthHrrmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg-month-cyclic/'
# segmonthcyclifileArray = []
# segmonthcyclirmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segmonthcyclifileArray.append(int(messFile[0]))
#         segmonthcyclirmseArray.append(float(rmse[0]))
    
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/knn/velocity/seg-timeStamp/'
# segtimeStampfileArray = []
# segtimeStamprmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         segtimeStampfileArray.append(int(messFile[0]))
#         segtimeStamprmseArray.append(float(rmse[0]))
    
# srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/stat/Velocity/'
# statsegfileArray = []
# statsegrmseArray = []
# for filename in os.listdir(srcDirectory):
#     messFile = filename.split('-')
#     rmse = messFile[1].split('.png')
#     if (int(messFile[0]) in a):
#         statsegfileArray.append(int(messFile[0]))
#         statsegrmseArray.append(float(rmse[0]))
    
#     if (int(messFile[0]) in a):
#         df = df.append({'MessFile': messFile[0],
#                     'stat': float(rmse[0]) }, ignore_index=True)
    
    


srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg/'
segfileArray = []
segrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segfileArray.append(int(messFile[0]))
        segrmseArray.append(float(rmse[0]))
    
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg-hour/'
seghourfileArray = []
seghourrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        seghourfileArray.append(int(messFile[0]))
        seghourrmseArray.append(float(rmse[0]))
    
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg-month/'
segmonthsegfileArray = []
segmonthrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthsegfileArray.append(int(messFile[0]))
        segmonthrmseArray.append(float(rmse[0]))
        
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg-month-hr/'
segmonthHrsegfileArray = []
segmonthHrrmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthHrsegfileArray.append(int(messFile[0]))
        segmonthHrrmseArray.append(float(rmse[0]))
    
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg-month-cyclic/'
segmonthcyclifileArray = []
segmonthcyclirmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segmonthcyclifileArray.append(int(messFile[0]))
        segmonthcyclirmseArray.append(float(rmse[0]))
    
    
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/RandomForest/velocity/seg-timeStamp/'
segtimeStampfileArray = []
segtimeStamprmseArray = []
for filename in os.listdir(srcDirectory):
    messFile = filename.split('-')
    rmse = messFile[1].split('.png')
    if (int(messFile[0]) in a):
        segtimeStampfileArray.append(int(messFile[0]))
        segtimeStamprmseArray.append(float(rmse[0]))

# %%
print("RandomForest-Seg===>", np.sum(segrmseArray)/6)
print("RandomForest-Seg-Hour===>",np.sum(seghourrmseArray)/6)
print("RandomForest-Seg-Month===>",np.sum(segmonthrmseArray)/6)
print("RandomForest-Seg-MonthCyclic===>",np.sum(segmonthcyclirmseArray)/6)
print("RandomForest-Seg-Month-Hour===>",np.sum(segmonthHrrmseArray)/6)
print("RandomForest-Seg-TimeStamp===>",np.sum(segtimeStamprmseArray)/6)

# print("Mean Prediction===>",np.sum(statsegrmseArray)/7)
# print("Random Forest -Seg -Month===>",np.sum(rfrmseArray)/7)
# Out:
# RandomForest-Seg===> 7.81500936942802
# RandomForest-Seg-Hour===> 10.36414506958082
# RandomForest-Seg-Month===> 8.503146912816524
# RandomForest-Seg-MonthCyclic===> 8.734351934947664
# RandomForest-Seg-Month-Hour===> 10.334633805905026
# RandomForest-Seg-TimeStamp===> 15.483774504953056

# %%
segtimeStamprmseArray
# Out:
# [11.548109177737343,
#  11.759739480685948,
#  10.889719940054524,
#  21.84222645873541,
#  9.712563777421252,
#  11.718122450723937,
#  15.432165744359914]

# %%
fig = plt.figure()
ax = fig.subplots()

ax.grid(which='both')
ax.set_xlabel("Measurement File")
ax.set_ylabel("RMSE (Temperature)")
major_ticks = np.arange(0, 100, 2)
minor_ticks = np.arange(0, 100, 1)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
plt.rcParams["figure.figsize"] = (20,5)

plt.plot(segfileArray, segrmseArray,c='red', label='wknn-Segment',linewidth=9)
plt.legend(loc='best')
#, alpha = 0.3, s= 170
plt.plot(seghourfileArray, seghourrmseArray,c='blue', label='wknn-Segment-Hour',linewidth=7,alpha=0.8)
plt.legend(loc='best')

plt.plot(segmonthsegfileArray, segmonthrmseArray,c='green', label='wknn-Segment-Month',linewidth=6,alpha=0.7)
plt.legend(loc='best')

plt.plot(segmonthcyclifileArray, segmonthcyclirmseArray,c='orange', label='wknn-Segment-Month-Cyclic',linewidth=3, alpha=0.7)
plt.legend(loc='best')

plt.plot(segtimeStampfileArray, segtimeStamprmseArray,c='pink', label='wknn-Segment-timestamp')
plt.legend(loc='best')

plt.plot(statsegfileArray, statsegrmseArray,c='black', label='Mean-Segment')
plt.legend(loc='best')

plt.plot(rffileArray, rfrmseArray,c='cyan', label='Random Forest-Segment')
plt.legend(loc='best')

path = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/TRIAL/images1/'
fig.savefig(path+'velocityRMSEcomparison',bbox_inches='tight') 
plt.ylim(0,8)
# Out:
# (0, 8)
