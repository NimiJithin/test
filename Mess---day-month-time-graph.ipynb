# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import pandasql as sql
import os
import matplotlib
import matplotlib.path as mpath
from matplotlib.collections import LineCollection
from datetime import datetime

# %%
filepath = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/AggregateMessurement/backupFinal/final2.csv'
finaldf = pd.read_csv(filepath)

# %%
testRoute = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/AggregateMessurement/Agg/m17.csv'
testRouteDF = pd.read_csv(testRoute)

# %%
testRouteDF.head()
# Out:
#    Unnamed: 0  Measured_order Measurement_file    Month      Day  \
# 0           0             0.0          m17.csv  January  Tuesday
# 1           1             1.0          m17.csv  January  Tuesday
# 2           2             2.0          m17.csv  January  Tuesday
# 3           3             3.0          m17.csv  January  Tuesday
# 4           4             4.0          m17.csv  January  Tuesday
#
#                    Start_Time                    End_Time  \
# 0  2018-01-09 17:59:07.040922  2018-01-09 17:59:49.540923
# 1  2018-01-09 17:59:49.540923  2018-01-09 17:59:50.540928
# 2  2018-01-09 17:59:50.540928  2018-01-09 17:59:51.540922
# 3  2018-01-09 17:59:51.540922  2018-01-09 17:59:52.540927
# 4  2018-01-09 17:59:52.540927  2018-01-09 17:59:53.540922
#
#                     Duration  Duration_in_hours  Duration_in_minutes  \
# 0  0 days 00:00:42.500001000           0.011806             0.708333
# 1  0 days 00:00:01.000005000           0.000278             0.016667
# ...

# %%
q2 = """SELECT * FROM finaldf where Day = 'Tuesday' and Measurement_file != 'm17.csv'and  Predicted_Seg IN (SELECT distinct(Predicted_Seg) FROM testRouteDF) """
test2 = sql.sqldf(q2, locals())

# %%
len(test2)
# Out:
# 1495

# %%
test2
# Out:
#        Unnamed: 0  Unnamed: 0.1  Measured_order Measurement_file    Month  \
# 0               0             0             0.0          m26.csv   August
# 1               1             1             1.0          m26.csv   August
# 2               3             3             3.0          m26.csv   August
# 3               4             4             4.0          m26.csv   August
# 4               5             5             5.0          m26.csv   August
# 5               6             6             6.0          m26.csv   August
# 6               7             7             7.0          m26.csv   August
# 7               8             8             8.0          m26.csv   August
# 8               9             9             9.0          m26.csv   August
# 9              10            10            10.0          m26.csv   August
# 10             11            11            11.0          m26.csv   August
# 11             12            12            12.0          m26.csv   August
# ...

# %%
tempDf = pd.DataFrame({'File':[],'Start':[], 'End':[]})

# %%
len(testRouteDF)
# Out:
# 1617

# %%
the_date1 = ms1.iloc[1]['time']

# %%
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/AggregateMessurement/Agg/'
for filename in os.listdir(srcDirectory):
    measuresdf = pd.read_csv(srcDirectory+filename)
    filename = filename[:-4]
    filename = filename[1:]
    ind = len(measuresdf)-1
    tempDf = tempDf.append({'File':filename, 
                            'Start':measuresdf.iloc[1]['Start_Time'], 
                            'End':measuresdf.iloc[ind]['End_Time'] }, ignore_index=True)

# %%
tempDf.head()
# Out:
#   File                       Start                         End
# 0    1  2017-11-01 16:17:58.835092  2017-11-01 17:05:36.835090
# 1   10  2017-11-28 16:20:56.652856  2017-11-28 17:06:49.152863
# 2   11  2017-12-01 12:32:31.415536  2017-12-01 13:17:02.915530
# 3   12  2017-12-01 13:27:41.119029  2017-12-01 14:13:25.119031
# 4   13  2017-12-04 12:59:53.159719  2017-12-04 13:44:42.659716

# %%
tempDf.dtypes
# Out:
# File              int32
# Start    datetime64[ns]
# End      datetime64[ns]
# dtype: object

# %%
tempDf['Start'] = pd.to_datetime(tempDf.Start)
tempDf['End'] = pd.to_datetime(tempDf.End)
tempDf['File'] = tempDf['File'].astype(str).astype(int)

# %%
#dates = matplotlib.dates.date2num(tempDf['Start'])
#matplotlib.pyplot.plot_date(matplotlib.dates.date2num(tempDf['Start']), tempDf.File)

# %%
tempDf['Start'] = tempDf['Start'].apply(lambda x: datetime.strftime(x, '%H'))

# %%
tempDf['Start'] = tempDf['Start'].astype(str).astype(int)

# %%
tempDf.Start.dtypes
# Out:
# dtype('int32')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Major ticks , minor ticks 
major_ticks = np.arange(0, 100, 20)
minor_ticks = np.arange(0, 100, 1)
major_ticksy = np.arange(0, 24, 2)
minor_ticksy = np.arange(0, 24, 1)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticksy)
ax.set_yticks(minor_ticksy, minor=True)

# And a corresponding grid
ax.grid(which='both')
plt.scatter(tempDf.File, tempDf.Start)
plt.rcParams["figure.figsize"] = (22,10)

plt.grid(axis='both')
plt.xlabel('Measurement_File')
plt.ylabel('Start_Time')
fig.savefig(srcDirectory+'.png',bbox_inches='tight')

# %%
tempDf = pd.DataFrame({'File':[],'Day':[], 'Month':[], 'Year':[]})

# %%
srcDirectory = 'C:/Users/NImi Jithin/Desktop/Studies/sem-3/research track/AggregateMessurement/Agg/'
for filename in os.listdir(srcDirectory):
    measuresdf = pd.read_csv(srcDirectory+filename)
    filename = filename[:-4]
    filename = filename[1:]
    #ind = len(measuresdf)-1
    tempDf = tempDf.append({'File':filename, 
                            'Day':measuresdf.iloc[1]['Day'], 
                            'Start':measuresdf.iloc[1]['Start_Time'],
                            'Month':measuresdf.iloc[1]['Month'] }, ignore_index=True)

# %%
tempDf['Start'] = pd.to_datetime(tempDf.Start)
tempDf['File'] = tempDf['File'].astype(str).astype(int)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Major ticks , minor ticks 
major_ticks = np.arange(0, 100, 5)
minor_ticks = np.arange(0, 100, 1)
major_ticksy = np.arange(0, 6, 2)
minor_ticksy = np.arange(0, 26, 1)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticksy)
ax.set_yticks(minor_ticksy, minor=True)

# And a corresponding grid
ax.grid(which='both')
plt.scatter(tempDf.File, tempDf.Day)
plt.rcParams["figure.figsize"] = (22,10)

plt.grid(axis='both')
plt.xlabel('Measurement_File')
plt.ylabel('Start_Time')
fig.savefig(srcDirectory+'.png',bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Major ticks , minor ticks 
major_ticks = np.arange(0, 100, 1)
minor_ticks = np.arange(0, 100, 1)
major_ticksy = np.arange(0, 12, 1)
minor_ticksy = np.arange(0, 12, 1)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticksy)
ax.set_yticks(minor_ticksy, minor=True)

# And a corresponding grid
ax.grid(which='both')
a = ax.get_xgridlines()
b = a[46]
b.set_color('red')
b.set_linewidth(2)

c = a[63]
c.set_color('red')
c.set_linewidth(2)

ax.scatter(tempDf.File, tempDf.Month)
#plt.rcParams["figure.figsize"] = (32,10)

#plt.grid(axis='both')
#plt.xlabel('Measurement_File')
#plt.ylabel('Month')
fig.savefig(srcDirectory+'.png',bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# And a corresponding grid
ax.grid(which='both')
ax.scatter((pd.to_timedelta(tempDf.Start).dt.total_seconds()), tempDf.Month)
#ax.scatter((pd.to_timedelta(tempDf.Start).dt.total_seconds()), tempDf.Month)
#plt.rcParams["figure.figsize"] = (32,10)

#plt.grid(axis='both')
#plt.xlabel('Measurement_File')
#plt.ylabel('Month')
fig.savefig(srcDirectory+'.png',bbox_inches='tight')
# Out:
# C:\ProgramData\AnacondaInstall\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#   import sys

# %%
print(a)
# Out:
# <a list of 20 Line2D xgridline objects>
